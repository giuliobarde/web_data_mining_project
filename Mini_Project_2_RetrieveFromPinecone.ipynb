# %% [markdown]
# <a href="https://colab.research.google.com/github/giuliobarde/web_data_mining_project/blob/main/Mini_Project_2_RetrieveFromPinecone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pinecone
# Out:
# Collecting pinecone
#   Downloading pinecone-6.0.2-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.11/dist-packages (from pinecone) (2025.1.31)
# Collecting pinecone-plugin-interface<0.0.8,>=0.0.7 (from pinecone)
#   Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from pinecone) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.11/dist-packages (from pinecone) (4.13.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from pinecone) (2.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.5.3->pinecone) (1.17.0)
# Downloading pinecone-6.0.2-py3-none-any.whl (421 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.9/421.9 kB 9.0 MB/s eta 0:00:00
# Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Installing collected packages: pinecone-plugin-interface, pinecone
# Successfully installed pinecone-6.0.2 pinecone-plugin-interface-0.0.7

# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.37.32-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore<1.38.0,>=1.37.32 (from boto3)
#   Downloading botocore-1.37.32-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.12.0,>=0.11.0 (from boto3)
#   Downloading s3transfer-0.11.4-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<1.38.0,>=1.37.32->boto3) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<1.38.0,>=1.37.32->boto3) (2.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.38.0,>=1.37.32->boto3) (1.17.0)
# Downloading boto3-1.37.32-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.6/139.6 kB 4.9 MB/s eta 0:00:00
# Downloading botocore-1.37.32-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 93.2 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.11.4-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.4/84.4 kB 6.6 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.37.32 botocore-1.37.32 jmespath-1.0.1 s3transfer-0.11.4

# %%
import json
import boto3
import pandas as pd
from typing import List, Dict, Any, Optional
import pinecone
import time
from botocore.config import Config
from botocore import UNSIGNED
import random
import requests

class NewsProcessor:
    """
    A class for processing news articles from S3 and storing them in Pinecone vector database.
    """

    def __init__(self, api_key: str, index_name: str, team_name: str, category: str):
        """
        Initialize the NewsProcessor with Pinecone credentials and team information.

        Args:
            api_key: Pinecone API key.
            index_name: Pinecone index name.
            team_name: Team name (e.g., 'Team 1').
            category: Assigned category (e.g., 'Health').
        """
        self.api_key = api_key
        self.index_name = index_name
        self.team_name = team_name
        self.category = category
        self.index = None

    def connect_to_pinecone(self) -> None:
        """Connect to Pinecone and initialize the index."""
        try:
            pinecone_client = pinecone.Pinecone(api_key=self.api_key, environment="us-east1-gcp")
            self.index = pinecone_client.Index(self.index_name)
            print(f"Connected to Pinecone index: {self.index_name}")
        except Exception as e:
            print(f"Error connecting to Pinecone: {str(e)}")
            print("Please check your API key, index name, and environment.")
            raise

    def fetch_from_s3(self, bucket_name: str, team_folder: str, category: str = None,
                      aws_access_key: str = None, aws_secret_key: str = None) -> List[Dict]:
        """
        Fetch news articles from S3 bucket.

        Args:
            bucket_name: S3 bucket name.
            team_folder: Team folder name (e.g., "TEAM_1/").
            category: Category to filter sources (optional).
            aws_access_key: AWS access key (optional).
            aws_secret_key: AWS secret key (optional).

        Returns:
            List of articles combined from all relevant source files.
        """
        # Initialize S3 client.
        if aws_access_key and aws_secret_key:
            s3_client = boto3.client(
                's3',
                aws_access_key_id=aws_access_key,
                aws_secret_access_key=aws_secret_key
            )
        else:
            s3_client = boto3.client('s3', config=Config(signature_version=UNSIGNED))

        try:
            # List all objects in the sources directory.
            sources_prefix = f"{team_folder}sources/"
            print(f"Listing objects in s3://{bucket_name}/{sources_prefix}")
            response = s3_client.list_objects_v2(Bucket=bucket_name, Prefix=sources_prefix)

            if 'Contents' not in response:
                print(f"No source files found in s3://{bucket_name}/{sources_prefix}")
                return []

            # Filter sources based on category
            source_files = []
            for obj in response['Contents']:
                file_key = obj['Key']
                if not file_key.endswith('.json'):
                    continue

                if category:
                    source_name = file_key.split('/')[-1].replace('.json', '')
                    if category.lower() in source_name.lower():
                        source_files.append(file_key)
                else:
                    source_files.append(file_key)

            print(f"Found {len(source_files)} source files")

            # Collect articles from all matching source files.
            all_articles = []
            for file_key in source_files:
                try:
                    print(f"Fetching {file_key}")
                    response = s3_client.get_object(Bucket=bucket_name, Key=file_key)
                    file_content = response['Body'].read().decode('utf-8')
                    source_data = json.loads(file_content)

                    for article_id, article in source_data.items():
                        article['source_file'] = file_key.split('/')[-1]
                        all_articles.append(article)

                    print(f"Added {len(source_data)} articles from {file_key}")
                except Exception as e:
                    print(f"Error processing {file_key}: {str(e)}")

            print(f"Total articles collected: {len(all_articles)}")
            return all_articles

        except Exception as e:
            print(f"Error fetching from S3: {str(e)}")
            if "AccessDenied" in str(e):
                print("Access denied. Check your IAM permissions or AWS credentials.")
            elif "NoSuchBucket" in str(e):
                print(f"Bucket '{bucket_name}' not found. Check the bucket name.")
            raise

    def process_articles(self, articles: List[Dict]) -> List[Dict]:
        """
        Process articles to prepare them for vector storage.
        """
        processed_articles = []
        for i, article in enumerate(articles):
            title = article.get('title')
            description = article.get('description')
            content = article.get('content')
            url = article.get('url')
            published_at = article.get('publishedAt')
            source_name = article.get('source', {}).get('name', '')
            source_file = article.get('source_file')
            author = article.get('author')

            text_content = f"Title: {title}\nDescription: {description}\nContent: {content}"

            processed_article = {
                'id': f"{self.team_name}_{self.category}_{source_name}_{i}",
                'text': text_content,
                'metadata': {
                    'team': self.team_name,
                    'category': self.category,
                    'title': title,
                    'url': url,
                    'published_at': published_at,
                    'source': source_name,
                    'source_file': source_file,
                    'author': author
                }
            }
            processed_articles.append(processed_article)
        return processed_articles

    def upload_to_pinecone(self, processed_articles: List[Dict]) -> None:
        """
        Upload processed articles to Pinecone.
        """
        if not self.index:
            raise ValueError("Not connected to Pinecone. Call connect_to_pinecone() first.")

        # Prepare records for upsert
        upsert_batch = []
        for article in processed_articles:
            random.seed(42)
            vector = [random.uniform(-0.01, 0.01) for _ in range(1024)]

            upsert_record = {
                'id': article['id'],
                'values': vector,
                'metadata': {
                    **article['metadata'],
                    'text': article['text']
                }
            }
            upsert_batch.append(upsert_record)

        batch_size = 10
        successful_uploads = 0
        for i in range(0, len(upsert_batch), batch_size):
            batch = upsert_batch[i:i+batch_size]
            try:
                self.index.upsert(vectors=batch)
                successful_uploads += len(batch)
                print(f"Uploaded batch {i//batch_size + 1}/{(len(upsert_batch)-1)//batch_size + 1}")
            except Exception as e:
                print(f"Error uploading batch {i//batch_size + 1}: {str(e)}")
                for j, record in enumerate(batch):
                    try:
                        self.index.upsert(vectors=[record])
                        successful_uploads += 1
                        print(f"  Successfully uploaded record {i+j+1}")
                    except Exception as e2:
                        print(f"  Failed to upload record {i+j+1}: {str(e2)}")

        print(f"Upload complete. Successfully uploaded {successful_uploads} out of {len(processed_articles)} articles.")

    def query_pinecone(self, query_text: str, top_k: int = 5, filter_params: Dict = None) -> List[Dict]:
        """
        Query Pinecone for similar articles.
        """
        if not self.index:
            raise ValueError("Not connected to Pinecone. Call connect_to_pinecone() first.")

        random.seed(42)
        vector = [random.uniform(-0.01, 0.01) for _ in range(1024)]

        query_params = {
            'top_k': top_k,
            'include_metadata': True,
        }
        if filter_params:
            query_params['filter'] = filter_params

        try:
            results = self.index.query(vector=vector, **query_params)
            return results.matches if hasattr(results, 'matches') else []
        except Exception as e:
            print(f"Error querying Pinecone: {str(e)}")
            return []

    def analyze_category_insights(self) -> Dict:
        """
        Analyze category-specific insights from stored articles.
        """
        filter_params = {
            'team': self.team_name,
            'category': self.category
        }

        category_queries = {
            'Health': ["medical research", "disease prevention", "healthcare policy", "wellness trends"],
            'Finance': ["stock market", "investment trends", "economic forecast", "financial news"],
            'Politics': ["election", "government policy", "political campaign", "international relations"],
            'Policies': ["regulation", "legislation", "policy reform", "government initiatives"],
            'World News': ["international events", "global crisis", "diplomatic relations", "world economy"],
            'Investment': ["stock performance", "investment strategy", "market analysis", "portfolio management"],
            'Leisure': ["entertainment", "sports events", "travel destinations", "recreational activities"]
        }
        queries = category_queries.get(self.category, ["trending topics", "recent developments", "major events"])

        insights = {}
        for query in queries:
            results = self.query_pinecone(query, top_k=3, filter_params=filter_params)
            insights[query] = results
        return insights

if __name__ == "__main__":
    processor = NewsProcessor(
        api_key="pcsk_6akU8Z_2BXXXDSBKbvFCn4sciNM2FeJC6PwAt6wFwQeQjoJKDSjysRbtyBAdUfRv6z87e6",
        index_name="cus635",
        team_name="Team 1",
        category="Finance"
    )

    # Connect to Pinecone
    processor.connect_to_pinecone()

    bucket_name = "cus635-spring2025"
    team_folder = "TEAM_1/"

    try:
        s3 = boto3.client('s3', config=Config(signature_version=UNSIGNED))
        print(f"Checking available folders in bucket: {bucket_name}")
        response = s3.list_objects_v2(Bucket=bucket_name, Delimiter="/")
        if 'CommonPrefixes' in response:
            print("Available team folders:")
            for prefix in response['CommonPrefixes']:
                print(f"- {prefix['Prefix']}")
        else:
            print("No team folders found. Checking all files in bucket...")
            response = s3.list_objects_v2(Bucket=bucket_name)
            if 'Contents' in response:
                for obj in response['Contents'][:10]:
                    print(f"- {obj['Key']}")
            else:
                print("No files found in bucket.")

        print(f"\nFetching articles from s3://{bucket_name}/{team_folder}")
        articles = processor.fetch_from_s3(bucket_name=bucket_name, team_folder=team_folder)
        if not articles:
            print("\nNo articles found in the default team folder. Trying TEAM_2/...")
            team_folder = "TEAM_2/"
            articles = processor.fetch_from_s3(bucket_name=bucket_name, team_folder=team_folder)

        if not articles:
            print("\nStill no articles found. Listing available files in the bucket for reference:")
            response = s3.list_objects_v2(Bucket=bucket_name)
            if 'Contents' in response:
                for obj in response['Contents'][:20]:
                    print(f"- {obj['Key']}")
            else:
                print("No files found in bucket. Please verify the bucket name and permissions.")
        else:
            processed_articles = processor.process_articles(articles)
            print(f"Processed {len(processed_articles)} articles, uploading to Pinecone...")
            processor.upload_to_pinecone(processed_articles)
            print("Upload complete!")

            print("\nPerforming sample query:")
            category_queries = {
                "Finance": ["stock market", "investment trends", "financial news"],
                "Health": ["medical research", "healthcare policy", "wellness trends"],
                "Politics": ["election", "government policy", "political debate"],
                "Policies": ["regulation", "legislation", "policy reform"],
                "World News": ["international relations", "global economy", "world events"],
                "Investment": ["stock market", "investment strategy", "portfolio management"],
                "Leisure": ["entertainment", "travel", "sports events"]
            }

            relevant_queries = category_queries.get(processor.category, ["trending topics"])
            for query in relevant_queries:
                print(f"\nQuerying for: '{query}'")
                query_results = processor.query_pinecone(query, top_k=3)
                for i, result in enumerate(query_results, 1):
                    print(f"{i}. {result.metadata.get('title')} (Score: {result.score:.4f})")
                    print(f"   Source: {result.metadata.get('source')}")

            print("\nAnalyzing category insights:")
            insights = processor.analyze_category_insights()
            for query, results in insights.items():
                print(f"\nInsights for '{query}':")
                for i, result in enumerate(results, 1):
                    print(f"{i}. {result.metadata.get('title')} (Score: {result.score:.4f})")

    except Exception as e:
        print(f"Error: {str(e)}")
        print("If you're facing S3 access issues, ensure your AWS credentials are configured correctly.")
# Out:
# Connected to Pinecone index: cus635
# Checking available folders in bucket: cus635-spring2025
# Available team folders:
# - TEAM_1/
# - TEAM_2/
# - TEAM_3/
# - TEAM_4/
# - TEAM_5/
# - TEAM_6/
# - TEAM_7/
# - TEAM_8/
#
# Fetching articles from s3://cus635-spring2025/TEAM_1/
# Listing objects in s3://cus635-spring2025/TEAM_1/sources/
# Found 58 source files
# Fetching TEAM_1/sources/ABC_News.json
# Added 9 articles from TEAM_1/sources/ABC_News.json
# Fetching TEAM_1/sources/ABC_News_AU_.json
# Added 1 articles from TEAM_1/sources/ABC_News_AU_.json
# Fetching TEAM_1/sources/ANSA_it.json
# Added 1 articles from TEAM_1/sources/ANSA_it.json
# Fetching TEAM_1/sources/AppleInsider.json
# Added 1 articles from TEAM_1/sources/AppleInsider.json
# Fetching TEAM_1/sources/Associated_Press.json
# Added 2 articles from TEAM_1/sources/Associated_Press.json
# Fetching TEAM_1/sources/BBC_News.json
# Added 4 articles from TEAM_1/sources/BBC_News.json
# Fetching TEAM_1/sources/BBC_Sport.json
# Added 4 articles from TEAM_1/sources/BBC_Sport.json
# Fetching TEAM_1/sources/Bild.json
# Added 2 articles from TEAM_1/sources/Bild.json
# Fetching TEAM_1/sources/Bleacher_Report.json
# Added 2 articles from TEAM_1/sources/Bleacher_Report.json
# Fetching TEAM_1/sources/Bloomberg.json
# Added 1 articles from TEAM_1/sources/Bloomberg.json
# Fetching TEAM_1/sources/Breitbart_News.json
# Added 1 articles from TEAM_1/sources/Breitbart_News.json
# Fetching TEAM_1/sources/Business_Insider.json
# Added 6 articles from TEAM_1/sources/Business_Insider.json
# Fetching TEAM_1/sources/CBC_News.json
# Added 1 articles from TEAM_1/sources/CBC_News.json
# Fetching TEAM_1/sources/CBS_News.json
# Added 2 articles from TEAM_1/sources/CBS_News.json
# Fetching TEAM_1/sources/CNET.json
# Added 1 articles from TEAM_1/sources/CNET.json
# Fetching TEAM_1/sources/CoinDesk.json
# Added 1 articles from TEAM_1/sources/CoinDesk.json
# Fetching TEAM_1/sources/Crypto_Coins_News.json
# Added 1 articles from TEAM_1/sources/Crypto_Coins_News.json
# Fetching TEAM_1/sources/Digital_Trends.json
# Added 1 articles from TEAM_1/sources/Digital_Trends.json
# Fetching TEAM_1/sources/ESPN.json
# Added 1 articles from TEAM_1/sources/ESPN.json
# Fetching TEAM_1/sources/Educatedguesswork_org.json
# Added 1 articles from TEAM_1/sources/Educatedguesswork_org.json
# Fetching TEAM_1/sources/Flowingdata_com.json
# Added 1 articles from TEAM_1/sources/Flowingdata_com.json
# Fetching TEAM_1/sources/FourFourTwo.json
# Added 1 articles from TEAM_1/sources/FourFourTwo.json
# Fetching TEAM_1/sources/Fox_News.json
# Added 1 articles from TEAM_1/sources/Fox_News.json
# Fetching TEAM_1/sources/Fox_Sports.json
# Added 1 articles from TEAM_1/sources/Fox_Sports.json
# Fetching TEAM_1/sources/Genbeta_com.json
# Added 2 articles from TEAM_1/sources/Genbeta_com.json
# Fetching TEAM_1/sources/Github_com.json
# Added 1 articles from TEAM_1/sources/Github_com.json
# Fetching TEAM_1/sources/Gizmodo_com.json
# Added 9 articles from TEAM_1/sources/Gizmodo_com.json
# Fetching TEAM_1/sources/Gizmodo_jp.json
# Added 2 articles from TEAM_1/sources/Gizmodo_jp.json
# Fetching TEAM_1/sources/Il_Sole_24_Ore.json
# Added 1 articles from TEAM_1/sources/Il_Sole_24_Ore.json
# Fetching TEAM_1/sources/Journal_du_geek.json
# Added 1 articles from TEAM_1/sources/Journal_du_geek.json
# Fetching TEAM_1/sources/Kaspersky_com.json
# Added 1 articles from TEAM_1/sources/Kaspersky_com.json
# Fetching TEAM_1/sources/L_equipe.json
# Added 1 articles from TEAM_1/sources/L_equipe.json
# Fetching TEAM_1/sources/Le_Monde.json
# Added 2 articles from TEAM_1/sources/Le_Monde.json
# Fetching TEAM_1/sources/MarketWatch.json
# Added 3 articles from TEAM_1/sources/MarketWatch.json
# Fetching TEAM_1/sources/NBC_News.json
# Added 2 articles from TEAM_1/sources/NBC_News.json
# Fetching TEAM_1/sources/NPR.json
# Added 3 articles from TEAM_1/sources/NPR.json
# Fetching TEAM_1/sources/News_com_au.json
# Added 1 articles from TEAM_1/sources/News_com_au.json
# Fetching TEAM_1/sources/Obscura_net.json
# Added 2 articles from TEAM_1/sources/Obscura_net.json
# Fetching TEAM_1/sources/Pluralistic_net.json
# Added 1 articles from TEAM_1/sources/Pluralistic_net.json
# Fetching TEAM_1/sources/Politico.json
# Added 1 articles from TEAM_1/sources/Politico.json
# Fetching TEAM_1/sources/Slashdot_org.json
# Added 2 articles from TEAM_1/sources/Slashdot_org.json
# Fetching TEAM_1/sources/Startupbaniya_com.json
# Added 1 articles from TEAM_1/sources/Startupbaniya_com.json
# Fetching TEAM_1/sources/TalkSport.json
# Added 1 articles from TEAM_1/sources/TalkSport.json
# Fetching TEAM_1/sources/The_Atlantic.json
# Added 1 articles from TEAM_1/sources/The_Atlantic.json
# Fetching TEAM_1/sources/The_Hill.json
# Added 3 articles from TEAM_1/sources/The_Hill.json
# Fetching TEAM_1/sources/The_Hindu.json
# Added 1 articles from TEAM_1/sources/The_Hindu.json
# Fetching TEAM_1/sources/The_Irish_Times.json
# Added 1 articles from TEAM_1/sources/The_Irish_Times.json
# Fetching TEAM_1/sources/The_Times_of_India.json
# Added 1 articles from TEAM_1/sources/The_Times_of_India.json
# Fetching TEAM_1/sources/The_Verge.json
# Added 3 articles from TEAM_1/sources/The_Verge.json
# Fetching TEAM_1/sources/The_Wall_Street_Journal.json
# Added 1 articles from TEAM_1/sources/The_Wall_Street_Journal.json
# Fetching TEAM_1/sources/The_Washington_Post.json
# Added 1 articles from TEAM_1/sources/The_Washington_Post.json
# Fetching TEAM_1/sources/Theregister_com.json
# Added 1 articles from TEAM_1/sources/Theregister_com.json
# Fetching TEAM_1/sources/Time.json
# Added 1 articles from TEAM_1/sources/Time.json
# Fetching TEAM_1/sources/Wired.json
# Added 2 articles from TEAM_1/sources/Wired.json
# Fetching TEAM_1/sources/Xataka_com.json
# Added 10 articles from TEAM_1/sources/Xataka_com.json
# Fetching TEAM_1/sources/Yahoo_Entertainment.json
# Added 10 articles from TEAM_1/sources/Yahoo_Entertainment.json
# Fetching TEAM_1/sources/Zeteo_com.json
# Added 1 articles from TEAM_1/sources/Zeteo_com.json
# Fetching TEAM_1/sources/heise_online.json
# Added 16 articles from TEAM_1/sources/heise_online.json
# Total articles collected: 137
# Processed 137 articles, uploading to Pinecone...
# Uploaded batch 1/14
# Error uploading batch 2: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:52 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '82', 'x-pinecone-request-id': '4122150566184496426', 'x-envoy-upstream-service-time': '21', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Successfully uploaded record 11
#   Successfully uploaded record 12
#   Successfully uploaded record 13
#   Successfully uploaded record 14
#   Failed to upload record 15: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:52 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1', 'x-pinecone-request-id': '5563137690673702556', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Failed to upload record 16: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:52 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '5434263555799595697', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Failed to upload record 17: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:52 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '2094490407272261605', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Successfully uploaded record 18
#   Failed to upload record 19: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:53 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1', 'x-pinecone-request-id': '9073959878252735045', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Failed to upload record 20: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:53 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '2552258968597146875', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
# Error uploading batch 3: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:53 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '59', 'x-pinecone-request-id': '432595449875440518', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Failed to upload record 21: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:53 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '5551744245335904219', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Failed to upload record 22: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:53 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '9041770519893014927', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Failed to upload record 23: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:53 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1', 'x-pinecone-request-id': '2918266882058766444', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Successfully uploaded record 24
#   Failed to upload record 25: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:53 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '7841830446930279862', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Failed to upload record 26: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:53 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '3283314661062943241', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Successfully uploaded record 27
#   Successfully uploaded record 28
#   Successfully uploaded record 29
#   Successfully uploaded record 30
# Error uploading batch 4: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:54 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1', 'x-pinecone-request-id': '9172271472982195692', 'x-envoy-upstream-service-time': '2', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Successfully uploaded record 31
#   Successfully uploaded record 32
#   Successfully uploaded record 33
#   Successfully uploaded record 34
#   Successfully uploaded record 35
#   Successfully uploaded record 36
#   Successfully uploaded record 37
#   Successfully uploaded record 38
#   Successfully uploaded record 39
#   Failed to upload record 40: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:55 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1', 'x-pinecone-request-id': '2231115975540086763', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
# Error uploading batch 5: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:55 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '2', 'x-pinecone-request-id': '7829851184782661367', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Successfully uploaded record 41
#   Successfully uploaded record 42
#   Failed to upload record 43: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:55 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '8236697536910892036', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Successfully uploaded record 44
#   Successfully uploaded record 45
#   Successfully uploaded record 46
#   Failed to upload record 47: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:56 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '7666229984996031677', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Successfully uploaded record 48
#   Successfully uploaded record 49
#   Successfully uploaded record 50
# Uploaded batch 6/14
# Error uploading batch 7: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:56 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '3099799041275492005', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Successfully uploaded record 61
#   Failed to upload record 62: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:57 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '5811422964045035937', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Successfully uploaded record 63
#   Failed to upload record 64: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:57 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '2792684783567914006', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Successfully uploaded record 65
#   Successfully uploaded record 66
#   Successfully uploaded record 67
#   Successfully uploaded record 68
#   Successfully uploaded record 69
#   Successfully uploaded record 70
# Error uploading batch 8: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:58 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1', 'x-pinecone-request-id': '8127427436613881604', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Successfully uploaded record 71
#   Successfully uploaded record 72
#   Successfully uploaded record 73
#   Successfully uploaded record 74
#   Successfully uploaded record 75
#   Successfully uploaded record 76
#   Failed to upload record 77: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:58 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '2717000737606908587', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Failed to upload record 78: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:58 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '7229930887157578438', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Failed to upload record 79: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:58 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '5697971234814886069', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Successfully uploaded record 80
# Uploaded batch 9/14
# Uploaded batch 10/14
# Uploaded batch 11/14
# Error uploading batch 12: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:59 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '7406084490669818411', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Failed to upload record 111: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:59 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '5024388398762971209', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Failed to upload record 112: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:15:59 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '2837605240178981923', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Successfully uploaded record 113
#   Failed to upload record 114: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:16:00 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '2995236096959942391', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Failed to upload record 115: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:16:00 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '8739176705781011968', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Failed to upload record 116: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:16:00 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '2911352784624724097', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Failed to upload record 117: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:16:00 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '985170176891025422', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Failed to upload record 118: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:16:00 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '5388834335434256458', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Failed to upload record 119: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:16:00 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '5936439821304228974', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
#   Failed to upload record 120: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 11 Apr 2025 00:16:00 GMT', 'Content-Type': 'application/json', 'Content-Length': '134', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '3127948624540138608', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Metadata value must be a string, number, boolean or list of strings, got 'null' for field 'author'","details":[]}
#
# Uploaded batch 13/14
# Uploaded batch 14/14
# Upload complete. Successfully uploaded 110 out of 137 articles.
# Upload complete!
#
# Performing sample query:
#
# Querying for: 'stock market'
# 1. WATCH: Endangered cheetah sanctuary breaks ground in Africa (Score: 1.0000)
#    Source: ABC News
# 2. WATCH: How social media helped fuel a female mechanic's business (Score: 1.0000)
#    Source: ABC News
# 3. White House crypto czar says public has 'lost out on over $17 billion' (Score: 1.0000)
#    Source: ABC News
#
# Querying for: 'investment trends'
# 1. WATCH: Endangered cheetah sanctuary breaks ground in Africa (Score: 1.0000)
#    Source: ABC News
# 2. WATCH: How social media helped fuel a female mechanic's business (Score: 1.0000)
#    Source: ABC News
# 3. White House crypto czar says public has 'lost out on over $17 billion' (Score: 1.0000)
#    Source: ABC News
#
# Querying for: 'financial news'
# 1. WATCH: Endangered cheetah sanctuary breaks ground in Africa (Score: 1.0000)
#    Source: ABC News
# 2. WATCH: How social media helped fuel a female mechanic's business (Score: 1.0000)
#    Source: ABC News
# 3. White House crypto czar says public has 'lost out on over $17 billion' (Score: 1.0000)
#    Source: ABC News
#
# Analyzing category insights:
#
# Insights for 'stock market':
# 1. WATCH: Endangered cheetah sanctuary breaks ground in Africa (Score: 1.0000)
# 2. WATCH: How social media helped fuel a female mechanic's business (Score: 1.0000)
# 3. White House crypto czar says public has 'lost out on over $17 billion' (Score: 1.0000)
#
# Insights for 'investment trends':
# 1. WATCH: Endangered cheetah sanctuary breaks ground in Africa (Score: 1.0000)
# 2. WATCH: How social media helped fuel a female mechanic's business (Score: 1.0000)
# 3. White House crypto czar says public has 'lost out on over $17 billion' (Score: 1.0000)
#
# Insights for 'economic forecast':
# 1. WATCH: Endangered cheetah sanctuary breaks ground in Africa (Score: 1.0000)
# 2. WATCH: How social media helped fuel a female mechanic's business (Score: 1.0000)
# 3. White House crypto czar says public has 'lost out on over $17 billion' (Score: 1.0000)
#
# Insights for 'financial news':
# 1. WATCH: Endangered cheetah sanctuary breaks ground in Africa (Score: 1.0000)
# 2. WATCH: How social media helped fuel a female mechanic's business (Score: 1.0000)
# 3. White House crypto czar says public has 'lost out on over $17 billion' (Score: 1.0000)
