# %%
import requests
import json

news_key = '116a9d5a70be4a3689c7b732a1a547d4'

# %%
query1 = 'sport'
url1 = (f'https://newsapi.org/v2/top-headlines?q={query1}&from=2025-02-01&sortBy=popularity&apiKey={news_key}')
response1 = requests.get(url1)

query2 = 'bitcoin'
url2 = (f'https://newsapi.org/v2/everything?q={query2}&from=2025-02-17&sortBy=popularity&apiKey={news_key}')
response2 = requests.get(url2)

# %%
response = response1.json()

#print(response1.json())
response1.json()
# Out:
# {'status': 'ok',
#  'totalResults': 34,
#  'articles': [{'source': {'id': 'bild', 'name': 'Bild'},
#    'author': 'Marco Werzinger, Nico Gelev, Martin Funk',
#    'title': 'FCN: Kommt jetzt doch noch die Aufstiegs-Attacke? | Sport',
#    'description': 'Der 1. FC Nürnberg hat durch das 0:0 bei Hertha BSC den Rückstand auf Relegationsplatz drei weiter verkleinert.',
#    'url': 'https://www.bild.de/sport/fussball/fcn-kommt-jetzt-doch-noch-die-aufstiegs-attacke-67bc764bdb9c805aefebcee8',
#    'urlToImage': 'https://images.bild.de/67bc764bdb9c805aefebcee8/7e7a4fa5b3b61d792f613d07335ef2e6,dd67053c?w=1280',
#    'publishedAt': '2025-02-24T23:31:48Z',
#    'content': 'Der Rückstand schmilzt und schmilzt und schmilzt...\r\nNach dem 16. Spieltag fehlten dem 1. FC Nürnberg neun Punkte auf Relegationsplatz drei. Der Aufstieg in die Bundesliga war am Valznerweiher überha… [+1971 chars]'},
#   {'source': {'id': 'bild', 'name': 'Bild'},
#    'author': 'Peter Wenzel, Max Backhaus',
# ...

# %%
for article in response['articles']:
    print(article.get('author', 'No author find'))
# Out:
# Marco Werzinger, Nico Gelev, Martin Funk
# Peter Wenzel, Max Backhaus
# Lukas Dombrowski, Kai-Uwe Hesse
# Max Backhaus
# Lisa Siegel
# Dennis Brosda, David Verhoff, Heiko Niedderer, Michel Schröer
# None
# dpa
# NRK
# None
# Ben Arthur
# None
# Briana Shepherd
# None
# Bruna Basini, Victoria Denys, Benjamin Martinez
# Sean Gregory / Boston
# Liam Hoofe
# None
# None
# ANSA.it
